# %%
from requests import Response, get
import json

res = get("https://realpython.com")
print("[{}] Response header:\n{}".format(__name__, json.dumps(dict(res.headers), indent=4)))
# Out:
# [__main__] Response header:
# {
#     "Date": "Thu, 20 Nov 2025 07:54:21 GMT",
#     "Content-Type": "text/html; charset=utf-8",
#     "Transfer-Encoding": "chunked",
#     "Connection": "keep-alive",
#     "cross-origin-opener-policy": "same-origin",
#     "nel": "{\"report_to\":\"heroku-nel\",\"response_headers\":[\"Via\"],\"max_age\":3600,\"success_fraction\":0.01,\"failure_fraction\":0.1}",
#     "referrer-policy": "strict-origin-when-cross-origin,origin",
#     "report-to": "{\"group\":\"heroku-nel\",\"endpoints\":[{\"url\":\"https://nel.heroku.com/reports?s=PNL9qN84uULdZ6j9DBnjkh9tB31P9wGSOsvAp9KdjhI%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1763625261\"}],\"max_age\":3600}",
#     "reporting-endpoints": "heroku-nel=\"https://nel.heroku.com/reports?s=PNL9qN84uULdZ6j9DBnjkh9tB31P9wGSOsvAp9KdjhI%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1763625261\"",
#     "Server": "cloudflare",
#     "strict-transport-security": "max-age=31536000; includeSubDomains; preload",
#     "vary": "Cookie, Accept-Encoding",
#     "via": "2.0 heroku-router",
#     "x-content-type-options": "nosniff",
#     "x-frame-options": "SAMEORIGIN",
#     "cf-cache-status": "DYNAMIC",
#     "Content-Encoding": "gzip",
#     "Set-Cookie": "dwf_exp_exit_popup=False; Secure; Path=/; Max-Age=2592000; Expires=Sat, 20 Dec 2025 07:54:21 GMT, csrftoken=nx2gWSe7Xt3mFZgvA8C3Vgh63knedoRk; SameSite=Lax; Secure; Path=/; Max-Age=31449600; Expires=Thu, 19 Nov 2026 07:54:21 GMT, cid=72f058e542674abcb3cd32eec7f9ea95; Path=/; Max-Age=31536000; Expires=Fri, 20 Nov 2026 07:54:21 GMT",
#     "CF-RAY": "9a1660fa1b898451-TPE",
#     "alt-svc": "h3=\":443\"; ma=86400"
# }

# %%
from pprint import PrettyPrinter
print = PrettyPrinter(
    # dict(res.headers),
    width=79,
    depth=3,
    compact=True,
    sort_dicts=False,
    # underscore_numbers=True
    )
print.pprint(dict(res.headers))
# Out:
# {'Date': 'Thu, 20 Nov 2025 07:54:21 GMT',
#  'Content-Type': 'text/html; charset=utf-8',
#  'Transfer-Encoding': 'chunked',
#  'Connection': 'keep-alive',
#  'cross-origin-opener-policy': 'same-origin',
#  'nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}',
#  'referrer-policy': 'strict-origin-when-cross-origin,origin',
#  'report-to': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=PNL9qN84uULdZ6j9DBnjkh9tB31P9wGSOsvAp9KdjhI%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1763625261"}],"max_age":3600}',
#  'reporting-endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=PNL9qN84uULdZ6j9DBnjkh9tB31P9wGSOsvAp9KdjhI%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1763625261"',
#  'Server': 'cloudflare',
#  'strict-transport-security': 'max-age=31536000; includeSubDomains; preload',
#  'vary': 'Cookie, Accept-Encoding',
#  'via': '2.0 heroku-router',
#  'x-content-type-options': 'nosniff',
#  'x-frame-options': 'SAMEORIGIN',
#  'cf-cache-status': 'DYNAMIC',
#  'Content-Encoding': 'gzip',
#  'Set-Cookie': 'dwf_exp_exit_popup=False; Secure; Path=/; Max-Age=2592000; '
#                'Expires=Sat, 20 Dec 2025 07:54:21 GMT, '
#                'csrftoken=nx2gWSe7Xt3mFZgvA8C3Vgh63knedoRk; SameSite=Lax; '
#                'Secure; Path=/; Max-Age=31449600; Expires=Thu, 19 Nov 2026 '
#                '07:54:21 GMT, cid=72f058e542674abcb3cd32eec7f9ea95; Path=/; '
#                'Max-Age=31536000; Expires=Fri, 20 Nov 2026 07:54:21 GMT',
#  'CF-RAY': '9a1660fa1b898451-TPE',
#  'alt-svc': 'h3=":443"; ma=86400'}
