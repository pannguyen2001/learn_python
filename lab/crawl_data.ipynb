# %% [markdown]
# ## Crawlee

# %%
import asyncio

from crawlee.crawlers import BeautifulSoupCrawler, BeautifulSoupCrawlingContext

final_data: list = []

async def main() -> None:
    
    crawler = BeautifulSoupCrawler(
        # Limit the crawl to max requests. Remove or increase it for crawling all links.
        max_requests_per_crawl=10,
    )

    # Define the default request handler, which will be called for every request.
    @crawler.router.default_handler
    async def request_handler(context: BeautifulSoupCrawlingContext) -> None:
        context.log.info(f'Processing {context.request.url} ...')

        # Extract data from the page.
        data = {
            'url': context.request.url,
            'title': context.soup.title.string if context.soup.title else None,
        }
        final_data.append(data)

        # Push the extracted data to the default dataset.
        await context.push_data(data)

        # Enqueue all links found on the page.
        await context.enqueue_links()

    # Run the crawler with the initial list of URLs.
    await crawler.run(['https://quotes.toscrape.com/'])


if __name__ == '__main__':
    await main()
    print(final_data)
# Out:
# Bad pipe message: %s [b' 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/148.0.0.0 Sa']
# Bad pipe message: %s [b'ri/537.36\r\nAccept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/', b'ng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nAccept-Encoding: gzip, deflate, br, zstd\r\nA']
# Bad pipe message: %s [b'ept-Language: vi,vi-VN;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5\r\nPriority: u=0, i\r\nReferer:', b'ttps://studio.firebase.google.c']
# Bad pipe message: %s [b'/\r\nSec-Ch-Ua: "Chromium";v="148", "Google Chrome";v="148", "Not/A)Brand";v="99"\r\nSec-Ch-Ua-Arch: "x86"\r\nSec-Ch', b'a-Bitness: "64"\r\nSec-Ch-Ua-Form-Factors: "De', b'top"\r\nSec-Ch-Ua-Full-Version: "148.0.7778.97"\r\nSec-Ch-Ua-Full-Version-List: "Chromium";v="148.0.7778.97", "Google ', b'rome";v="148.0.7778.97", "Not/A)Brand";v="99.0.0.0"\r\nSec-Ch-Ua-Mob']
# Bad pipe message: %s [b'e: ?0\r\nSec-Ch-Ua-Model: ""\r\nSec-Ch-Ua-Platform: "Windows"\r\nSec-Ch-Ua-Platform-Version: "19.0.0"\r\nSec-Ch-']
# Bad pipe message: %s [b'-Wow64: ?0\r\nSec-Fetch-Dest: iframe\r\nSec-Fetch-Mode: navigate\r\nSec-Fetch-Site: cross-', b'te\r\nSec-Fetch-Storage-Access: active\r\nSec-Fetch-User: ?1\r\nSec-User-Ip: 222.255.139.6\r\nUpgrade-Insecure-Requests: 1', b'X-Forwarded-']
# Bad pipe message: %s [b'st: 44601-firebase-datacrawling-1774544805630.cluster-nzwlpk54dvagsxetk', b'zbvslyi.cloudworkstations.dev\r\nX-Goog-Workstations-Endpoint: workstations-7d0938e6-2c58-4e89-9a77-b4501b959127.asia-e']
# [BeautifulSoupCrawler] INFO  Current request statistics:
# ┌───────────────────────────────┬──────┐
# │ requests_finished             │ 0    │
# │ requests_failed               │ 0    │
# │ retry_histogram               │ [0]  │
# │ request_avg_failed_duration   │ None │
# │ request_avg_finished_duration │ None │
# │ requests_finished_per_minute  │ 0    │
# │ requests_failed_per_minute    │ 0    │
# │ request_total_duration        │ 0s   │
# │ requests_total                │ 0    │
# │ crawler_runtime               │ 0s   │
# └───────────────────────────────┴──────┘
# [BeautifulSoupCrawler] INFO  Crawled 0/1 pages, 0 failed requests, desired concurrency 10.
# [crawlee._autoscaling.autoscaled_pool] INFO  current_concurrency = 0; desired_concurrency = 10; cpu = 0; mem = 0; event_loop = 0.0; client_info = 0.0
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/deep-thoughts/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/world/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/thinking/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/abilities/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/change/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/choices/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/login ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/inspirational/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/author/Albert-Einstein ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/author/J-K-Rowling ...
# [BeautifulSoupCrawler] INFO  Crawler.stop() was called with following reason: The crawler has reached its limit of 10 requests per crawl. .
# [BeautifulSoupCrawler] INFO  The crawler will finish any remaining ongoing requests and shut down.
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/live/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/aliteracy/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/life/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/miracle/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/miracles/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/classic/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/tag/books/page/1/ ...
# [BeautifulSoupCrawler] INFO  Processing https://quotes.toscrape.com/author/Jane-Austen ...
# [crawlee._autoscaling.autoscaled_pool] INFO  Waiting for remaining tasks to finish
# [BeautifulSoupCrawler] INFO  Final request statistics:
# ┌───────────────────────────────┬─────────┐
# │ requests_finished             │ 19      │
# │ requests_failed               │ 0       │
# │ retry_histogram               │ [19]    │
# │ request_avg_failed_duration   │ None    │
# │ request_avg_finished_duration │ 824.7ms │
# │ requests_finished_per_minute  │ 380     │
# │ requests_failed_per_minute    │ 0       │
# │ request_total_duration        │ 15.67s  │
# │ requests_total                │ 19      │
# │ crawler_runtime               │ 3.00s   │
# └───────────────────────────────┴─────────┘
# [{'url': 'https://quotes.toscrape.com/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/deep-thoughts/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/world/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/thinking/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/abilities/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/change/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/choices/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/login', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/inspirational/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/author/Albert-Einstein', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/author/J-K-Rowling', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/live/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/aliteracy/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/life/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/miracle/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/miracles/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/classic/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/tag/books/page/1/', 'title': 'Quotes to Scrape'}, {'url': 'https://quotes.toscrape.com/author/Jane-Austen', 'title': 'Quotes to Scrape'}]

# %%
import polars as pl
# Show all rows and all columns globally
pl.Config.set_tbl_rows(-1)
pl.Config.set_tbl_cols(-1)

df_final_data = pl.DataFrame(final_data)

df_final_data
# Out:
# shape: (19, 2)
# ┌─────────────────────────────────┬──────────────────┐
# │ url                             ┆ title            │
# │ ---                             ┆ ---              │
# │ str                             ┆ str              │
# ╞═════════════════════════════════╪══════════════════╡
# │ https://quotes.toscrape.com/    ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/lo… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/au… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/au… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/ta… ┆ Quotes to Scrape │
# │ https://quotes.toscrape.com/au… ┆ Quotes to Scrape │
# └─────────────────────────────────┴──────────────────┘

# %%
import asyncio

from crawlee.crawlers import BeautifulSoupCrawler, BeautifulSoupCrawlingContext


async def main() -> None:
    crawler = BeautifulSoupCrawler(
        # Limit the crawl to max requests. Remove or increase it for crawling all links.
        max_requests_per_crawl=10,
    )

    # Define the default request handler, which will be called for every request.
    @crawler.router.default_handler
    async def request_handler(context: BeautifulSoupCrawlingContext) -> None:
        context.log.info(f'Processing {context.request.url} ...')

        # Enqueue all links found on the page.
        await context.enqueue_links()

    # Run the crawler with the initial list of requests.
    await crawler.run(['https://crawlee.dev'])


if __name__ == '__main__':
    await main()
# Out:
# [BeautifulSoupCrawler] INFO  Current request statistics:
# ┌───────────────────────────────┬──────┐
# │ requests_finished             │ 0    │
# │ requests_failed               │ 0    │
# │ retry_histogram               │ [0]  │
# │ request_avg_failed_duration   │ None │
# │ request_avg_finished_duration │ None │
# │ requests_finished_per_minute  │ 0    │
# │ requests_failed_per_minute    │ 0    │
# │ request_total_duration        │ 0s   │
# │ requests_total                │ 0    │
# │ crawler_runtime               │ 0s   │
# └───────────────────────────────┴──────┘
# [BeautifulSoupCrawler] INFO  Crawled 0/1103 pages, 0 failed requests, desired concurrency 10.
# [crawlee._autoscaling.autoscaled_pool] INFO  current_concurrency = 0; desired_concurrency = 10; cpu = 0; mem = 0; event_loop = 0.0; client_info = 0.0
# [BeautifulSoupCrawler] INFO  Processing https://crawlee.dev/js/api/core/class/SystemStatus ...
# [BeautifulSoupCrawler] INFO  Processing https://crawlee.dev/js/api/core/class/Request ...
# [BeautifulSoupCrawler] INFO  Processing https://crawlee.dev/js/api/core/class/RequestList ...
# [BeautifulSoupCrawler] INFO  Processing https://crawlee.dev/js/api/core/enum/LogLevel ...
# [BeautifulSoupCrawler] INFO  Processing https://crawlee.dev/js/api/core/class/RequestQueue ...
# [BeautifulSoupCrawler] INFO  Processing https://crawlee.dev/js/api/core/class/Snapshotter ...
# [BeautifulSoupCrawler] INFO  Processing https://crawlee.dev/js/api/core/class/RequestQueueV1 ...
# [BeautifulSoupCrawler] INFO  Processing https://crawlee.dev/js/api/core/enum/RequestState ...
# [BeautifulSoupCrawler] INFO  Processing https://crawlee.dev/js/api/core/class/PseudoUrl ...
# [BeautifulSoupCrawler] INFO  Processing https://crawlee.dev/js/api/core/enum/EventType ...
# [BeautifulSoupCrawler] INFO  Crawler.stop() was called with following reason: The crawler has reached its limit of 10 requests per crawl. .
# [BeautifulSoupCrawler] INFO  The crawler will finish any remaining ongoing requests and shut down.
# [crawlee._autoscaling.autoscaled_pool] INFO  Waiting for remaining tasks to finish
# [BeautifulSoupCrawler] INFO  Final request statistics:
# ┌───────────────────────────────┬────────┐
# │ requests_finished             │ 10     │
# │ requests_failed               │ 0      │
# │ retry_histogram               │ [10]   │
# │ request_avg_failed_duration   │ None   │
# │ request_avg_finished_duration │ 1.04s  │
# │ requests_finished_per_minute  │ 480    │
# │ requests_failed_per_minute    │ 0      │
# │ request_total_duration        │ 10.44s │
# │ requests_total                │ 10     │
# │ crawler_runtime               │ 1.25s  │
# └───────────────────────────────┴────────┘
