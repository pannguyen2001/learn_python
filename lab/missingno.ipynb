# %% [markdown]
# ### try missingno package
#
# use for visualize missing data
#
# https://www.nb-data.com/p/how-to-visualize-missing-data-patterns
#
# https://book.the-turing-way.org/project-design/missing-data/missing-data-visualising-missingness/
#
# https://www.kaggle.com/code/selahattinsanli/visualizing-missing-data

# %%
# !pip install missingno

# %%
import pandas as pd
import numpy as np
df = pd.read_excel("/home/user/py-pannguyen-learn/data/raw/sales_data_sample.xlsx", sheet_name="Sales_Data")
df
# Out:
#       Order_ID       Date        Category   Region Customer_Segment  \
# 0    ORD-10000 2024-07-12           Books     East         Business
# 1    ORD-10001 2025-03-15          Sports     West          Premium
# 2    ORD-10002 2024-12-27  Home & Kitchen  Central         Business
# 3    ORD-10003 2024-07-16  Home & Kitchen    North          Regular
# 4    ORD-10004 2024-06-11     Electronics    North              New
# ..         ...        ...             ...      ...              ...
# 995  ORD-10995 2024-08-20          Sports    North              New
# 996  ORD-10996 2025-02-14     Electronics  Central         Business
# 997  ORD-10997 2024-05-08           Books     West          Premium
# 998  ORD-10998 2025-01-18        Clothing    South              New
# 999  ORD-10999 2024-08-17          Sports     East          Regular
#
#        Payment_Method  Quantity  Unit_Price  Discount_Rate  Customer_Rating  \
# ...

# %%
import missingno as msno
msno.heatmap(df)
# Out:
# <Axes: >

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.dendrogram(df)
# Out:
# <Axes: >
